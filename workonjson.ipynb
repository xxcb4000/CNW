# %%
import pandas as pd
df = pd.read_json('Balades.json')
df
# Out:
#        SAISON  SEASON BODY_SAISON   SAISONLEVELHEADER_URL DURATION  \
# 0   Printemps  spring  bodyspring          springeasy.jpg       1h
# 1   Printemps  spring  bodyspring  springintermediate.jpg       2h
# 2   Printemps  spring  bodyspring          springhard.jpg       4h
# 3         Été  summer  bodysummer          summereasy.jpg       1h
# 4         Été  summer  bodysummer  summerintermediate.jpg       2h
# 5         Été  summer  bodysummer          summerhard.jpg       4h
# 6     Automne    fall    bodyfall            falleasy.jpg       1h
# 7     Automne    fall    bodyfall    fallintermediate.jpg       2h
# 8     Automne    fall    bodyfall            fallhard.jpg       4h
# 9       Hiver  winter  bodywinter          wintereasy.jpg       1h
# 10      Hiver  winter  bodywinter  winterintermediate.jpg       2h
# 11      Hiver  winter  bodywinter          winterhard.jpg       4h
#
#                 LOCATION               NOM_WALK  \
# ...
